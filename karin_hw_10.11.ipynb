# %%
For X = 0.1, the three nearest X values are 0.3, 0.5, and 0.8
The Y values of those are 1.3, 1.5, and 2.0
Their average is roughly (1.3 + 1.5 + 2.0) / 3 =1.6
So, we can say the predicted Y for X = 0.1 is about 1.6
The real Y was 1.0, so the prediction is close — nice!

 X = 0.3

Nearest X: 0.1, 0.5, 0.8
Nearest Y: 1.0, 1.5, 2.0

Predicted Y = (1.0 + 1.5 + 2.0) / 3 = 1.5
Real Y = 1.3

 X = 0.5

Nearest X: 0.3, 0.8, 1.1
Nearest Y: 1.3, 2.0, 2.4

Predicted Y = (1.3 + 2.0 + 2.4) / 3 = 1.9
Real Y = 1.5

 X = 0.8

Nearest X: 0.5, 1.1, 1.5
Nearest Y: 1.5, 2.4, 2.9

Predicted Y = (1.5 + 2.4 + 2.9) / 3 = 2.27
Real Y = 2.0

 X = 1.1

Nearest X: 0.8, 1.5, 1.9
Nearest Y: 2.0, 2.9, 3.3

Predicted Y = (2.0 + 2.9 + 3.3) / 3 = 2.73
Real Y = 2.4

 X = 1.5

Nearest X: 1.1, 1.9, 2.3
Nearest Y: 2.4, 3.3, 3.8

Predicted Y = (2.4 + 3.3 + 3.8) / 3 = 3.17
Real Y = 2.9

 X = 1.9

Nearest X: 1.5, 2.3, 2.8
Nearest Y: 2.9, 3.8, 4.4

Predicted Y = (2.9 + 3.8 + 4.4) / 3 = 3.7
Real Y = 3.3

 X = 2.3

Nearest X: 1.9, 2.8, 3.3
Nearest Y: 3.3, 4.4, 5.0

Predicted Y = (3.3 + 4.4 + 5.0) / 3 = 4.23
Real Y = 3.8

 X = 2.8

Nearest X: 2.3, 3.3, 3.7
Nearest Y: 3.8, 5.0, 5.4

Predicted Y = (3.8 + 5.0 + 5.4) / 3 = 4.73
Real Y = 4.4

X = 3.3

Nearest X: 2.8, 3.7, 4.2
Nearest Y: 4.4, 5.4, 6.0

Predicted Y = (4.4 + 5.4 + 6.0) / 3 = 5.27
Real Y = 5.0

 X = 3.7

Nearest X: 3.3, 4.2, 2.8
Nearest Y: 5.0, 6.0, 4.4

Predicted Y = (5.0 + 6.0 + 4.4) / 3 = 5.13
Real Y = 5.4

 X = 4.2

Nearest X: 3.7, 3.3, 2.8
Nearest Y: 5.4, 5.0, 4.4

Predicted Y = (5.4 + 5.0 + 4.4) / 3 = 4.93
Real Y = 6.0

# %%
import numpy as np

Y_true = np.array([1.0, 1.3, 1.5, 2.0, 2.4, 2.9, 3.3, 3.8, 4.4, 5.0, 5.4, 6.0])
Y_pred = np.array([1.6, 1.5, 1.9, 2.27, 2.73, 3.17, 3.7, 4.23, 4.73, 5.27, 5.13, 4.93])

mse = np.mean((Y_true - Y_pred)**2)
print(mse)
# Out:
# 0.2132666666666668
